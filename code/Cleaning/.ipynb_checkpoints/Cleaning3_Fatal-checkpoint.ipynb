# %% [markdown]
# # Fatality Table Cleaning
#
# Our collected industry fatalities data is organized by state, rather than year.    The below process will combine all state fatality data in tables by year.

# %%
import pandas as pd

# %%
def f_year2010(df):
    # give columns relevant names
    df.columns = ['State','Total_Fatalities','Construction_Fatalities']
    # taking only data for year (in this case, 2010)
    df = df.iloc[0:2,:]
    df.drop(0, inplace=True)
    # set index to the state name
    df.set_index('State',drop=True,inplace=True)
    return df

# %%
AL= pd.read_csv('../data/cleaned_data/fatalities/AL_fatalc.csv').T.reset_index().replace('2010_Total','Alabama')

# %%
AL = f_year2010(AL)
# Out:
# C:\Users\justanotheregg\Anaconda3\envs\dsi\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
AL
# Out:
#         Total_Fatalities Construction_Fatalities
# State
# Alabama               92                      15

# %% [markdown]
# We will now activate the function all all years, with minor adjustments.

# %%
# all 2010
AK= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/AK_fatalc.csv').T.reset_index().replace('2010_Total','Alaska') )
AR= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/AR_fatalc.csv').T.reset_index().replace('2010_Total','Arkansas'))
AZ= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/AZ_fatalc.csv').T.reset_index().replace('2010_Total','Arizona'))
CA= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/CA_fatalc.csv').T.reset_index().replace('2010_Total','California'))
CO= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/CO_fatalc.csv').T.reset_index().replace('2010_Total','Colorado'))
CT= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/CT_fatalc.csv').T.reset_index().replace('2010_Total','Connecticut'))
DE= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/DE_fatalc.csv').T.reset_index().replace('2010_Total','Delaware'))
DC= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/DC_fatalc.csv').T.reset_index().replace('2010_Total','District of Columbia'))
FL= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/FL_fatalc.csv').T.reset_index().replace('2010_Total','Florida'))
GA= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/GA_fatalc.csv').T.reset_index().replace('2010_Total','Georgia'))
HI= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/HI_fatalc.csv').T.reset_index().replace('2010_Total','Hawaii'))
IA= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/IA_fatalc.csv').T.reset_index().replace('2010_Total','Iowa'))
ID= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/ID_fatalc.csv').T.reset_index().replace('2010_Total','Idaho'))
IL= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/IL_fatalc.csv').T.reset_index().replace('2010_Total','Illinois'))
IN= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/IN_fatalc.csv').T.reset_index().replace('2010_Total','Indiana'))
KS= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/KS_fatalc.csv').T.reset_index().replace('2010_Total','Kansas'))
KY= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/KY_fatalc.csv').T.reset_index().replace('2010_Total','Kentucky'))
LA= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/LA_fatalc.csv').T.reset_index().replace('2010_Total','Louisiana'))
MA= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/MA_fatalc.csv').T.reset_index().replace('2010_Total','Massachusetts'))
ME= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/ME_fatalc.csv').T.reset_index().replace('2010_Total','Maine'))
MD= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/MD_fatalc.csv').T.reset_index().replace('2010_Total','Maryland'))
MI= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/MI_fatalc.csv').T.reset_index().replace('2010_Total','Michigan'))
MN= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/MN_fatalc.csv').T.reset_index().replace('2010_Total','Minnesota'))
MO= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/MO_fatalc.csv').T.reset_index().replace('2010_Total','Missouri'))
MS= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/MS_fatalc.csv').T.reset_index().replace('2010_Total','Mississippi'))
MT= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/MT_fatalc.csv').T.reset_index().replace('2010_Total','Montana'))
NC= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/NC_fatalc.csv').T.reset_index().replace('2010_Total','North Carolina'))
ND= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/ND_fatalc.csv').T.reset_index().replace('2010_Total','North Dakota'))
NE= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/NE_fatalc.csv').T.reset_index().replace('2010_Total','Nebraska'))
NH= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/NH_fatalc.csv').T.reset_index().replace('2010_Total','New Hampshire'))
NJ= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/NJ_fatalc.csv').T.reset_index().replace('2010_Total','New Jersey'))
NM= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/NM_fatalc.csv').T.reset_index().replace('2010_Total','New Mexico'))
NV= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/NV_fatalc.csv').T.reset_index().replace('2010_Total','Nevada'))
NY= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/NY_fatalc.csv').T.reset_index().replace('2010_Total','New York'))
OH= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/OH_fatalc.csv').T.reset_index().replace('2010_Total','Ohio'))
OK= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/OK_fatalc.csv').T.reset_index().replace('2010_Total','Oklahoma'))
OR= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/OR_fatalc.csv').T.reset_index().replace('2010_Total','Oregon'))
PA= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/PA_fatalc.csv').T.reset_index().replace('2010_Total','Pennsylvania'))
RI= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/RI_fatalc.csv').T.reset_index().replace('2010_Total','Rhode Island'))
SC= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/SC_fatalc.csv').T.reset_index().replace('2010_Total','South Carolina'))
SD= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/SD_fatalc.csv').T.reset_index().replace('2010_Total','South Dakota'))
TN= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/TN_fatalc.csv').T.reset_index().replace('2010_Total','Tennessee'))
TX= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/TX_fatalc.csv').T.reset_index().replace('2010_Total','Texas'))
UT= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/UT_fatalc.csv').T.reset_index().replace('2010_Total','Utah'))
VA= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/VA_fatalc.csv').T.reset_index().replace('2010_Total','Virginia'))
VT= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/VT_fatalc.csv').T.reset_index().replace('2010_Total','Vermont'))
WA= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/WA_fatalc.csv').T.reset_index().replace('2010_Total','Washington'))
WI= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/WI_fatalc.csv').T.reset_index().replace('2010_Total','Wisconsin'))
WV= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/WV_fatalc.csv').T.reset_index().replace('2010_Total','West Virginia'))
WY= f_year2010(pd.read_csv('../data/cleaned_data/fatalities/WY_fatalc.csv').T.reset_index().replace('2010_Total', 'Wyoming'))

# %%
# consolidating state data into one table, saving to csv
f_2010 = pd.concat([AL,AK,AR,AZ,CA,CO,CT,DE,DC,
FL,GA,HI,IA,ID,IL,IN,KS,KY,LA,
MA,ME,MD,MI,MN,MO,MS,
MT,NC,ND,NE,NH,NJ,NM,
NV,NY,OH,OK,OR,PA,
RI,SC,SD,TN,TX,UT,
VA,VT,WA,WI,WV,WY])
f_2010.to_csv('../data/cleaned_data/model_data/2010/f_2010.csv')

# %%
def f_year2011(df):
    df.columns = ['State','Total_Fatalities','Construction_Fatalities']
    df = df.iloc[1:3,:].drop(1)
    df.set_index('State',drop=True,inplace=True)
    return df

# %%
# all 2011 data

AL= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/AL_fatalc.csv').T.reset_index().replace('2011_Total','Alabama'))
AK= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/AK_fatalc.csv').T.reset_index().replace('2011_Total','Alaska'))
AR= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/AR_fatalc.csv').T.reset_index().replace('2011_Total','Arkansas'))
AZ= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/AZ_fatalc.csv').T.reset_index().replace('2011_Total','Arizona'))
CA= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/CA_fatalc.csv').T.reset_index().replace('2011_Total','California'))
CO= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/CO_fatalc.csv').T.reset_index().replace('2011_Total','Colorado'))
CT= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/CT_fatalc.csv').T.reset_index().replace('2011_Total','Connecticut'))
DE= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/DE_fatalc.csv').T.reset_index().replace('2011_Total','Delaware'))
DC= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/DC_fatalc.csv').T.reset_index().replace('2011_Total','District of Columbia'))
FL= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/FL_fatalc.csv').T.reset_index().replace('2011_Total','Florida'))
GA= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/GA_fatalc.csv').T.reset_index().replace('2011_Total','Georgia'))
HI= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/HI_fatalc.csv').T.reset_index().replace('2011_Total','Hawaii'))
IA= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/IA_fatalc.csv').T.reset_index().replace('2011_Total','Iowa'))
ID= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/ID_fatalc.csv').T.reset_index().replace('2011_Total','Idaho'))
IL= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/IL_fatalc.csv').T.reset_index().replace('2011_Total','Illinois'))
IN= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/IN_fatalc.csv').T.reset_index().replace('2011_Total','Indiana'))
KS= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/KS_fatalc.csv').T.reset_index().replace('2011_Total','Kansas'))
KY= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/KY_fatalc.csv').T.reset_index().replace('2011_Total','Kentucky'))
LA= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/LA_fatalc.csv').T.reset_index().replace('2011_Total','Louisiana'))
MA= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/MA_fatalc.csv').T.reset_index().replace('2011_Total','Massachusetts'))
ME= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/ME_fatalc.csv').T.reset_index().replace('2011_Total','Maine'))
MD= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/MD_fatalc.csv').T.reset_index().replace('2011_Total','Maryland'))
MI= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/MI_fatalc.csv').T.reset_index().replace('2011_Total','Michigan'))
MN= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/MN_fatalc.csv').T.reset_index().replace('2011_Total','Minnesota'))
MO= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/MO_fatalc.csv').T.reset_index().replace('2011_Total','Missouri'))
MS= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/MS_fatalc.csv').T.reset_index().replace('2011_Total','Mississippi'))
MT= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/MT_fatalc.csv').T.reset_index().replace('2011_Total','Montana'))
NC= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/NC_fatalc.csv').T.reset_index().replace('2011_Total','North Carolina'))
ND= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/ND_fatalc.csv').T.reset_index().replace('2011_Total','North Dakota'))
NE= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/NE_fatalc.csv').T.reset_index().replace('2011_Total','Nebraska'))
NH= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/NH_fatalc.csv').T.reset_index().replace('2011_Total','New Hampshire'))
NJ= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/NJ_fatalc.csv').T.reset_index().replace('2011_Total','New Jersey'))
NM= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/NM_fatalc.csv').T.reset_index().replace('2011_Total','New Mexico'))
NV= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/NV_fatalc.csv').T.reset_index().replace('2011_Total','Nevada'))
NY= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/NY_fatalc.csv').T.reset_index().replace('2011_Total','New York'))
OH= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/OH_fatalc.csv').T.reset_index().replace('2011_Total','Ohio'))
OK= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/OK_fatalc.csv').T.reset_index().replace('2011_Total','Oklahoma'))
OR= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/OR_fatalc.csv').T.reset_index().replace('2011_Total','Oregon'))
PA= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/PA_fatalc.csv').T.reset_index().replace('2011_Total','Pennsylvania'))
RI= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/RI_fatalc.csv').T.reset_index().replace('2011_Total','Rhode Island'))
SC= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/SC_fatalc.csv').T.reset_index().replace('2011_Total','South Carolina'))
SD= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/SD_fatalc.csv').T.reset_index().replace('2011_Total','South Dakota'))
TN= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/TN_fatalc.csv').T.reset_index().replace('2011_Total','Tennessee'))
TX= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/TX_fatalc.csv').T.reset_index().replace('2011_Total','Texas'))
UT= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/UT_fatalc.csv').T.reset_index().replace('2011_Total','Utah'))
VA= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/VA_fatalc.csv').T.reset_index().replace('2011_Total','Virginia'))
VT= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/VT_fatalc.csv').T.reset_index().replace('2011_Total','Vermont'))
WA= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/WA_fatalc.csv').T.reset_index().replace('2011_Total','Washington'))
WI= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/WI_fatalc.csv').T.reset_index().replace('2011_Total','Wisconsin'))
WV= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/WV_fatalc.csv').T.reset_index().replace('2011_Total','West Virginia'))
WY= f_year2011(pd.read_csv('../data/cleaned_data/fatalities/WY_fatalc.csv').T.reset_index().replace('2011_Total', 'Wyoming'))

# %%
f_2011 = pd.concat([AL,AK,AR,AZ,CA,CO,CT,DE,DC,
FL,GA,HI,IA,ID,IL,IN,KS,KY,LA,
MA,ME,MD,MI,MN,MO,MS,
MT,NC,ND,NE,NH,NJ,NM,
NV,NY,OH,OK,OR,PA,
RI,SC,SD,TN,TX,UT,
VA,VT,WA,WI,WV,WY])

f_2011.to_csv('../data/cleaned_data/model_data/2011/f_2011.csv')

# %%
def f_year2012(df):
    df.columns = ['State','Total_Fatalities','Construction_Fatalities']
    df = df.iloc[3:4,:]
    df.set_index('State',drop=True,inplace=True)
    return df

# %%
# 2012
AL= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/AL_fatalc.csv').T.reset_index().replace('2012_Total','Alabama'))
AK= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/AK_fatalc.csv').T.reset_index().replace('2012_Total','Alaska'))
AR= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/AR_fatalc.csv').T.reset_index().replace('2012_Total','Arkansas'))
AZ= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/AZ_fatalc.csv').T.reset_index().replace('2012_Total','Arizona'))
CA= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/CA_fatalc.csv').T.reset_index().replace('2012_Total','California'))
CO= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/CO_fatalc.csv').T.reset_index().replace('2012_Total','Colorado'))
CT= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/CT_fatalc.csv').T.reset_index().replace('2012_Total','Connecticut'))
DE= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/DE_fatalc.csv').T.reset_index().replace('2012_Total','Delaware'))
DC= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/DC_fatalc.csv').T.reset_index().replace('2012_Total','District of Columbia'))
FL= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/FL_fatalc.csv').T.reset_index().replace('2012_Total','Florida'))
GA= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/GA_fatalc.csv').T.reset_index().replace('2012_Total','Georgia'))
HI= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/HI_fatalc.csv').T.reset_index().replace('2012_Total','Hawaii'))
IA= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/IA_fatalc.csv').T.reset_index().replace('2012_Total','Iowa'))
ID= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/ID_fatalc.csv').T.reset_index().replace('2012_Total','Idaho'))
IL= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/IL_fatalc.csv').T.reset_index().replace('2012_Total','Illinois'))
IN= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/IN_fatalc.csv').T.reset_index().replace('2012_Total','Indiana'))
KS= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/KS_fatalc.csv').T.reset_index().replace('2012_Total','Kansas'))
KY= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/KY_fatalc.csv').T.reset_index().replace('2012_Total','Kentucky'))
LA= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/LA_fatalc.csv').T.reset_index().replace('2012_Total','Louisiana'))
MA= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/MA_fatalc.csv').T.reset_index().replace('2012_Total','Massachusetts'))
ME= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/ME_fatalc.csv').T.reset_index().replace('2012_Total','Maine'))
MD= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/MD_fatalc.csv').T.reset_index().replace('2012_Total','Maryland'))
MI= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/MI_fatalc.csv').T.reset_index().replace('2012_Total','Michigan'))
MN= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/MN_fatalc.csv').T.reset_index().replace('2012_Total','Minnesota'))
MO= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/MO_fatalc.csv').T.reset_index().replace('2012_Total','Missouri'))
MS= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/MS_fatalc.csv').T.reset_index().replace('2012_Total','Mississippi'))
MT= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/MT_fatalc.csv').T.reset_index().replace('2012_Total','Montana'))
NC= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/NC_fatalc.csv').T.reset_index().replace('2012_Total','North Carolina'))
ND= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/ND_fatalc.csv').T.reset_index().replace('2012_Total','North Dakota'))
NE= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/NE_fatalc.csv').T.reset_index().replace('2012_Total','Nebraska'))
NH= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/NH_fatalc.csv').T.reset_index().replace('2012_Total','New Hampshire'))
NJ= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/NJ_fatalc.csv').T.reset_index().replace('2012_Total','New Jersey'))
NM= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/NM_fatalc.csv').T.reset_index().replace('2012_Total','New Mexico'))
NV= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/NV_fatalc.csv').T.reset_index().replace('2012_Total','Nevada'))
NY= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/NY_fatalc.csv').T.reset_index().replace('2012_Total','New York'))
OH= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/OH_fatalc.csv').T.reset_index().replace('2012_Total','Ohio'))
OK= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/OK_fatalc.csv').T.reset_index().replace('2012_Total','Oklahoma'))
OR= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/OR_fatalc.csv').T.reset_index().replace('2012_Total','Oregon'))
PA= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/PA_fatalc.csv').T.reset_index().replace('2012_Total','Pennsylvania'))
RI= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/RI_fatalc.csv').T.reset_index().replace('2012_Total','Rhode Island'))
SC= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/SC_fatalc.csv').T.reset_index().replace('2012_Total','South Carolina'))
SD= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/SD_fatalc.csv').T.reset_index().replace('2012_Total','South Dakota'))
TN= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/TN_fatalc.csv').T.reset_index().replace('2012_Total','Tennessee'))
TX= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/TX_fatalc.csv').T.reset_index().replace('2012_Total','Texas'))
UT= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/UT_fatalc.csv').T.reset_index().replace('2012_Total','Utah'))
VA= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/VA_fatalc.csv').T.reset_index().replace('2012_Total','Virginia'))
VT= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/VT_fatalc.csv').T.reset_index().replace('2012_Total','Vermont'))
WA= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/WA_fatalc.csv').T.reset_index().replace('2012_Total','Washington'))
WI= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/WI_fatalc.csv').T.reset_index().replace('2012_Total','Wisconsin'))
WV= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/WV_fatalc.csv').T.reset_index().replace('2012_Total','West Virginia'))
WY= f_year2012(pd.read_csv('../data/cleaned_data/fatalities/WY_fatalc.csv').T.reset_index().replace('2012_Total', 'Wyoming'))

# %%
f_2012 = pd.concat([AL,AK,AR,AZ,CA,CO,CT,DE,DC,
FL,GA,HI,IA,ID,IL,IN,KS,KY,LA,
MA,ME,MD,MI,MN,MO,MS,
MT,NC,ND,NE,NH,NJ,NM,
NV,NY,OH,OK,OR,PA,
RI,SC,SD,TN,TX,UT,
VA,VT,WA,WI,WV,WY])

f_2012.to_csv('../data/cleaned_data/model_data/2012/f_2012.csv')

# %%
def f_year2013(df):
    df.columns = ['State','Total_Fatalities','Construction_Fatalities']
    df = df.iloc[4:5,:]
    df.set_index('State',drop=True,inplace=True)
    return df

# %%
# 2013
AL= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/AL_fatalc.csv').T.reset_index().replace('2013_Total','Alabama'))
AK= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/AK_fatalc.csv').T.reset_index().replace('2013_Total','Alaska'))
AR= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/AR_fatalc.csv').T.reset_index().replace('2013_Total','Arkansas'))
AZ= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/AZ_fatalc.csv').T.reset_index().replace('2013_Total','Arizona'))
CA= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/CA_fatalc.csv').T.reset_index().replace('2013_Total','California'))
CO= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/CO_fatalc.csv').T.reset_index().replace('2013_Total','Colorado'))
CT= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/CT_fatalc.csv').T.reset_index().replace('2013_Total','Connecticut'))
DE= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/DE_fatalc.csv').T.reset_index().replace('2013_Total','Delaware'))
DC= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/DC_fatalc.csv').T.reset_index().replace('2013_Total','District of Columbia'))
FL= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/FL_fatalc.csv').T.reset_index().replace('2013_Total','Florida'))
GA= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/GA_fatalc.csv').T.reset_index().replace('2013_Total','Georgia'))
HI= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/HI_fatalc.csv').T.reset_index().replace('2013_Total','Hawaii'))
IA= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/IA_fatalc.csv').T.reset_index().replace('2013_Total','Iowa'))
ID= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/ID_fatalc.csv').T.reset_index().replace('2013_Total','Idaho'))
IL= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/IL_fatalc.csv').T.reset_index().replace('2013_Total','Illinois'))
IN= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/IN_fatalc.csv').T.reset_index().replace('2013_Total','Indiana'))
KS= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/KS_fatalc.csv').T.reset_index().replace('2013_Total','Kansas'))
KY= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/KY_fatalc.csv').T.reset_index().replace('2013_Total','Kentucky'))
LA= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/LA_fatalc.csv').T.reset_index().replace('2013_Total','Louisiana'))
MA= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/MA_fatalc.csv').T.reset_index().replace('2013_Total','Massachusetts'))
ME= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/ME_fatalc.csv').T.reset_index().replace('2013_Total','Maine'))
MD= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/MD_fatalc.csv').T.reset_index().replace('2013_Total','Maryland'))
MI= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/MI_fatalc.csv').T.reset_index().replace('2013_Total','Michigan'))
MN= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/MN_fatalc.csv').T.reset_index().replace('2013_Total','Minnesota'))
MO= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/MO_fatalc.csv').T.reset_index().replace('2013_Total','Missouri'))
MS= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/MS_fatalc.csv').T.reset_index().replace('2013_Total','Mississippi'))
MT= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/MT_fatalc.csv').T.reset_index().replace('2013_Total','Montana'))
NC= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/NC_fatalc.csv').T.reset_index().replace('2013_Total','North Carolina'))
ND= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/ND_fatalc.csv').T.reset_index().replace('2013_Total','North Dakota'))
NE= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/NE_fatalc.csv').T.reset_index().replace('2013_Total','Nebraska'))
NH= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/NH_fatalc.csv').T.reset_index().replace('2013_Total','New Hampshire'))
NJ= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/NJ_fatalc.csv').T.reset_index().replace('2013_Total','New Jersey'))
NM= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/NM_fatalc.csv').T.reset_index().replace('2013_Total','New Mexico'))
NV= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/NV_fatalc.csv').T.reset_index().replace('2013_Total','Nevada'))
NY= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/NY_fatalc.csv').T.reset_index().replace('2013_Total','New York'))
OH= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/OH_fatalc.csv').T.reset_index().replace('2013_Total','Ohio'))
OK= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/OK_fatalc.csv').T.reset_index().replace('2013_Total','Oklahoma'))
OR= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/OR_fatalc.csv').T.reset_index().replace('2013_Total','Oregon'))
PA= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/PA_fatalc.csv').T.reset_index().replace('2013_Total','Pennsylvania'))
RI= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/RI_fatalc.csv').T.reset_index().replace('2013_Total','Rhode Island'))
SC= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/SC_fatalc.csv').T.reset_index().replace('2013_Total','South Carolina'))
SD= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/SD_fatalc.csv').T.reset_index().replace('2013_Total','South Dakota'))
TN= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/TN_fatalc.csv').T.reset_index().replace('2013_Total','Tennessee'))
TX= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/TX_fatalc.csv').T.reset_index().replace('2013_Total','Texas'))
UT= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/UT_fatalc.csv').T.reset_index().replace('2013_Total','Utah'))
VA= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/VA_fatalc.csv').T.reset_index().replace('2013_Total','Virginia'))
VT= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/VT_fatalc.csv').T.reset_index().replace('2013_Total','Vermont'))
WA= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/WA_fatalc.csv').T.reset_index().replace('2013_Total','Washington'))
WI= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/WI_fatalc.csv').T.reset_index().replace('2013_Total','Wisconsin'))
WV= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/WV_fatalc.csv').T.reset_index().replace('2013_Total','West Virginia'))
WY= f_year2013(pd.read_csv('../data/cleaned_data/fatalities/WY_fatalc.csv').T.reset_index().replace('2013_Total', 'Wyoming'))

# %%
f_2013 = pd.concat([AL,AK,AR,AZ,CA,CO,CT,DE,DC,
FL,GA,HI,IA,ID,IL,IN,KS,KY,LA,
MA,ME,MD,MI,MN,MO,MS,
MT,NC,ND,NE,NH,NJ,NM,
NV,NY,OH,OK,OR,PA,
RI,SC,SD,TN,TX,UT,
VA,VT,WA,WI,WV,WY])

f_2013.to_csv('../data/cleaned_data/model_data/2013/f_2013.csv')

# %%
def f_year2014(df):
    df.columns = ['State','Total_Fatalities','Construction_Fatalities']
    df = df.iloc[5:6,:]
    df.set_index('State',drop=True,inplace=True)
    return df

# %%
# 2014

AL= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/AL_fatalc.csv').T.reset_index().replace('2014_Total','Alabama'))
AK= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/AK_fatalc.csv').T.reset_index().replace('2014_Total','Alaska'))
AR= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/AR_fatalc.csv').T.reset_index().replace('2014_Total','Arkansas'))
AZ= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/AZ_fatalc.csv').T.reset_index().replace('2014_Total','Arizona'))
CA= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/CA_fatalc.csv').T.reset_index().replace('2014_Total','California'))
CO= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/CO_fatalc.csv').T.reset_index().replace('2014_Total','Colorado'))
CT= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/CT_fatalc.csv').T.reset_index().replace('2014_Total','Connecticut'))
DE= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/DE_fatalc.csv').T.reset_index().replace('2014_Total','Delaware'))
DC= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/DC_fatalc.csv').T.reset_index().replace('2014_Total','District of Columbia'))
FL= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/FL_fatalc.csv').T.reset_index().replace('2014_Total','Florida'))
GA= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/GA_fatalc.csv').T.reset_index().replace('2014_Total','Georgia'))
HI= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/HI_fatalc.csv').T.reset_index().replace('2014_Total','Hawaii'))
IA= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/IA_fatalc.csv').T.reset_index().replace('2014_Total','Iowa'))
ID= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/ID_fatalc.csv').T.reset_index().replace('2014_Total','Idaho'))
IL= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/IL_fatalc.csv').T.reset_index().replace('2014_Total','Illinois'))
IN= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/IN_fatalc.csv').T.reset_index().replace('2014_Total','Indiana'))
KS= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/KS_fatalc.csv').T.reset_index().replace('2014_Total','Kansas'))
KY= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/KY_fatalc.csv').T.reset_index().replace('2014_Total','Kentucky'))
LA= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/LA_fatalc.csv').T.reset_index().replace('2014_Total','Louisiana'))
MA= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/MA_fatalc.csv').T.reset_index().replace('2014_Total','Massachusetts'))
ME= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/ME_fatalc.csv').T.reset_index().replace('2014_Total','Maine'))
MD= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/MD_fatalc.csv').T.reset_index().replace('2014_Total','Maryland'))
MI= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/MI_fatalc.csv').T.reset_index().replace('2014_Total','Michigan'))
MN= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/MN_fatalc.csv').T.reset_index().replace('2014_Total','Minnesota'))
MO= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/MO_fatalc.csv').T.reset_index().replace('2014_Total','Missouri'))
MS= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/MS_fatalc.csv').T.reset_index().replace('2014_Total','Mississippi'))
MT= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/MT_fatalc.csv').T.reset_index().replace('2014_Total','Montana'))
NC= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/NC_fatalc.csv').T.reset_index().replace('2014_Total','North Carolina'))
ND= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/ND_fatalc.csv').T.reset_index().replace('2014_Total','North Dakota'))
NE= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/NE_fatalc.csv').T.reset_index().replace('2014_Total','Nebraska'))
NH= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/NH_fatalc.csv').T.reset_index().replace('2014_Total','New Hampshire'))
NJ= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/NJ_fatalc.csv').T.reset_index().replace('2014_Total','New Jersey'))
NM= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/NM_fatalc.csv').T.reset_index().replace('2014_Total','New Mexico'))
NV= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/NV_fatalc.csv').T.reset_index().replace('2014_Total','Nevada'))
NY= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/NY_fatalc.csv').T.reset_index().replace('2014_Total','New York'))
OH= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/OH_fatalc.csv').T.reset_index().replace('2014_Total','Ohio'))
OK= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/OK_fatalc.csv').T.reset_index().replace('2014_Total','Oklahoma'))
OR= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/OR_fatalc.csv').T.reset_index().replace('2014_Total','Oregon'))
PA= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/PA_fatalc.csv').T.reset_index().replace('2014_Total','Pennsylvania'))
RI= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/RI_fatalc.csv').T.reset_index().replace('2014_Total','Rhode Island'))
SC= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/SC_fatalc.csv').T.reset_index().replace('2014_Total','South Carolina'))
SD= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/SD_fatalc.csv').T.reset_index().replace('2014_Total','South Dakota'))
TN= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/TN_fatalc.csv').T.reset_index().replace('2014_Total','Tennessee'))
TX= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/TX_fatalc.csv').T.reset_index().replace('2014_Total','Texas'))
UT= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/UT_fatalc.csv').T.reset_index().replace('2014_Total','Utah'))
VA= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/VA_fatalc.csv').T.reset_index().replace('2014_Total','Virginia'))
VT= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/VT_fatalc.csv').T.reset_index().replace('2014_Total','Vermont'))
WA= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/WA_fatalc.csv').T.reset_index().replace('2014_Total','Washington'))
WI= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/WI_fatalc.csv').T.reset_index().replace('2014_Total','Wisconsin'))
WV= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/WV_fatalc.csv').T.reset_index().replace('2014_Total','West Virginia'))
WY= f_year2014(pd.read_csv('../data/cleaned_data/fatalities/WY_fatalc.csv').T.reset_index().replace('2014_Total', 'Wyoming'))

# %%
f_2014 = pd.concat([AL,AK,AR,AZ,CA,CO,CT,DE,DC,
FL,GA,HI,IA,ID,IL,IN,KS,KY,LA,
MA,ME,MD,MI,MN,MO,MS,
MT,NC,ND,NE,NH,NJ,NM,
NV,NY,OH,OK,OR,PA,
RI,SC,SD,TN,TX,UT,
VA,VT,WA,WI,WV,WY])

f_2014.to_csv('../data/cleaned_data/model_data/2014/f_2014.csv')

# %%
def f_year2015(df):
    df.columns = ['State','Total_Fatalities','Construction_Fatalities']
    df = df.iloc[6:7,:]
    df.set_index('State',drop=True,inplace=True)
    return df

# %%
# 2015
AL= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/AL_fatalc.csv').T.reset_index().replace('2015_Total','Alabama'))
AK= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/AK_fatalc.csv').T.reset_index().replace('2015_Total','Alaska'))
AR= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/AR_fatalc.csv').T.reset_index().replace('2015_Total','Arkansas'))
AZ= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/AZ_fatalc.csv').T.reset_index().replace('2015_Total','Arizona'))
CA= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/CA_fatalc.csv').T.reset_index().replace('2015_Total','California'))
CO= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/CO_fatalc.csv').T.reset_index().replace('2015_Total','Colorado'))
CT= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/CT_fatalc.csv').T.reset_index().replace('2015_Total','Connecticut'))
DE= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/DE_fatalc.csv').T.reset_index().replace('2015_Total','Delaware'))
DC= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/DC_fatalc.csv').T.reset_index().replace('2015_Total','District of Columbia'))
FL= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/FL_fatalc.csv').T.reset_index().replace('2015_Total','Florida'))
GA= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/GA_fatalc.csv').T.reset_index().replace('2015_Total','Georgia'))
HI= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/HI_fatalc.csv').T.reset_index().replace('2015_Total','Hawaii'))
IA= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/IA_fatalc.csv').T.reset_index().replace('2015_Total','Iowa'))
ID= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/ID_fatalc.csv').T.reset_index().replace('2015_Total','Idaho'))
IL= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/IL_fatalc.csv').T.reset_index().replace('2015_Total','Illinois'))
IN= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/IN_fatalc.csv').T.reset_index().replace('2015_Total','Indiana'))
KS= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/KS_fatalc.csv').T.reset_index().replace('2015_Total','Kansas'))
KY= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/KY_fatalc.csv').T.reset_index().replace('2015_Total','Kentucky'))
LA= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/LA_fatalc.csv').T.reset_index().replace('2015_Total','Louisiana'))
MA= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/MA_fatalc.csv').T.reset_index().replace('2015_Total','Massachusetts'))
ME= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/ME_fatalc.csv').T.reset_index().replace('2015_Total','Maine'))
MD= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/MD_fatalc.csv').T.reset_index().replace('2015_Total','Maryland'))
MI= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/MI_fatalc.csv').T.reset_index().replace('2015_Total','Michigan'))
MN= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/MN_fatalc.csv').T.reset_index().replace('2015_Total','Minnesota'))
MO= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/MO_fatalc.csv').T.reset_index().replace('2015_Total','Missouri'))
MS= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/MS_fatalc.csv').T.reset_index().replace('2015_Total','Mississippi'))
MT= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/MT_fatalc.csv').T.reset_index().replace('2015_Total','Montana'))
NC= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/NC_fatalc.csv').T.reset_index().replace('2015_Total','North Carolina'))
ND= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/ND_fatalc.csv').T.reset_index().replace('2015_Total','North Dakota'))
NE= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/NE_fatalc.csv').T.reset_index().replace('2015_Total','Nebraska'))
NH= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/NH_fatalc.csv').T.reset_index().replace('2015_Total','New Hampshire'))
NJ= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/NJ_fatalc.csv').T.reset_index().replace('2015_Total','New Jersey'))
NM= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/NM_fatalc.csv').T.reset_index().replace('2015_Total','New Mexico'))
NV= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/NV_fatalc.csv').T.reset_index().replace('2015_Total','Nevada'))
NY= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/NY_fatalc.csv').T.reset_index().replace('2015_Total','New York'))
OH= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/OH_fatalc.csv').T.reset_index().replace('2015_Total','Ohio'))
OK= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/OK_fatalc.csv').T.reset_index().replace('2015_Total','Oklahoma'))
OR= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/OR_fatalc.csv').T.reset_index().replace('2015_Total','Oregon'))
PA= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/PA_fatalc.csv').T.reset_index().replace('2015_Total','Pennsylvania'))
RI= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/RI_fatalc.csv').T.reset_index().replace('2015_Total','Rhode Island'))
SC= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/SC_fatalc.csv').T.reset_index().replace('2015_Total','South Carolina'))
SD= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/SD_fatalc.csv').T.reset_index().replace('2015_Total','South Dakota'))
TN= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/TN_fatalc.csv').T.reset_index().replace('2015_Total','Tennessee'))
TX= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/TX_fatalc.csv').T.reset_index().replace('2015_Total','Texas'))
UT= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/UT_fatalc.csv').T.reset_index().replace('2015_Total','Utah'))
VA= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/VA_fatalc.csv').T.reset_index().replace('2015_Total','Virginia'))
VT= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/VT_fatalc.csv').T.reset_index().replace('2015_Total','Vermont'))
WA= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/WA_fatalc.csv').T.reset_index().replace('2015_Total','Washington'))
WI= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/WI_fatalc.csv').T.reset_index().replace('2015_Total','Wisconsin'))
WV= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/WV_fatalc.csv').T.reset_index().replace('2015_Total','West Virginia'))
WY= f_year2015(pd.read_csv('../data/cleaned_data/fatalities/WY_fatalc.csv').T.reset_index().replace('2015_Total', 'Wyoming'))

# %%
f_2015 = pd.concat([AL,AK,AR,AZ,CA,CO,CT,DE,DC,
FL,GA,HI,IA,ID,IL,IN,KS,KY,LA,
MA,ME,MD,MI,MN,MO,MS,
MT,NC,ND,NE,NH,NJ,NM,
NV,NY,OH,OK,OR,PA,
RI,SC,SD,TN,TX,UT,
VA,VT,WA,WI,WV,WY])

f_2015.to_csv('../data/cleaned_data/model_data/2015/f_2015.csv')

# %%
def f_year2016(df):
    df.columns = ['State','Total_Fatalities','Construction_Fatalities']
    df = df.iloc[7:8,:]
    df.set_index('State',drop=True,inplace=True)
    return df

# %%
# 2016
AL= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/AL_fatalc.csv').T.reset_index().replace('2016_Total','Alabama'))
AK= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/AK_fatalc.csv').T.reset_index().replace('2016_Total','Alaska'))
AR= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/AR_fatalc.csv').T.reset_index().replace('2016_Total','Arkansas'))
AZ= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/AZ_fatalc.csv').T.reset_index().replace('2016_Total','Arizona'))
CA= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/CA_fatalc.csv').T.reset_index().replace('2016_Total','California'))
CO= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/CO_fatalc.csv').T.reset_index().replace('2016_Total','Colorado'))
CT= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/CT_fatalc.csv').T.reset_index().replace('2016_Total','Connecticut'))
DE= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/DE_fatalc.csv').T.reset_index().replace('2016_Total','Delaware'))
DC= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/DC_fatalc.csv').T.reset_index().replace('2016_Total','District of Columbia'))
FL= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/FL_fatalc.csv').T.reset_index().replace('2016_Total','Florida'))
GA= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/GA_fatalc.csv').T.reset_index().replace('2016_Total','Georgia'))
HI= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/HI_fatalc.csv').T.reset_index().replace('2016_Total','Hawaii'))
IA= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/IA_fatalc.csv').T.reset_index().replace('2016_Total','Iowa'))
ID= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/ID_fatalc.csv').T.reset_index().replace('2016_Total','Idaho'))
IL= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/IL_fatalc.csv').T.reset_index().replace('2016_Total','Illinois'))
IN= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/IN_fatalc.csv').T.reset_index().replace('2016_Total','Indiana'))
KS= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/KS_fatalc.csv').T.reset_index().replace('2016_Total','Kansas'))
KY= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/KY_fatalc.csv').T.reset_index().replace('2016_Total','Kentucky'))
LA= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/LA_fatalc.csv').T.reset_index().replace('2016_Total','Louisiana'))
MA= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/MA_fatalc.csv').T.reset_index().replace('2016_Total','Massachusetts'))
ME= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/ME_fatalc.csv').T.reset_index().replace('2016_Total','Maine'))
MD= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/MD_fatalc.csv').T.reset_index().replace('2016_Total','Maryland'))
MI= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/MI_fatalc.csv').T.reset_index().replace('2016_Total','Michigan'))
MN= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/MN_fatalc.csv').T.reset_index().replace('2016_Total','Minnesota'))
MO= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/MO_fatalc.csv').T.reset_index().replace('2016_Total','Missouri'))
MS= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/MS_fatalc.csv').T.reset_index().replace('2016_Total','Mississippi'))
MT= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/MT_fatalc.csv').T.reset_index().replace('2016_Total','Montana'))
NC= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/NC_fatalc.csv').T.reset_index().replace('2016_Total','North Carolina'))
ND= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/ND_fatalc.csv').T.reset_index().replace('2016_Total','North Dakota'))
NE= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/NE_fatalc.csv').T.reset_index().replace('2016_Total','Nebraska'))
NH= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/NH_fatalc.csv').T.reset_index().replace('2016_Total','New Hampshire'))
NJ= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/NJ_fatalc.csv').T.reset_index().replace('2016_Total','New Jersey'))
NM= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/NM_fatalc.csv').T.reset_index().replace('2016_Total','New Mexico'))
NV= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/NV_fatalc.csv').T.reset_index().replace('2016_Total','Nevada'))
NY= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/NY_fatalc.csv').T.reset_index().replace('2016_Total','New York'))
OH= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/OH_fatalc.csv').T.reset_index().replace('2016_Total','Ohio'))
OK= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/OK_fatalc.csv').T.reset_index().replace('2016_Total','Oklahoma'))
OR= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/OR_fatalc.csv').T.reset_index().replace('2016_Total','Oregon'))
PA= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/PA_fatalc.csv').T.reset_index().replace('2016_Total','Pennsylvania'))
RI= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/RI_fatalc.csv').T.reset_index().replace('2016_Total','Rhode Island'))
SC= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/SC_fatalc.csv').T.reset_index().replace('2016_Total','South Carolina'))
SD= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/SD_fatalc.csv').T.reset_index().replace('2016_Total','South Dakota'))
TN= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/TN_fatalc.csv').T.reset_index().replace('2016_Total','Tennessee'))
TX= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/TX_fatalc.csv').T.reset_index().replace('2016_Total','Texas'))
UT= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/UT_fatalc.csv').T.reset_index().replace('2016_Total','Utah'))
VA= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/VA_fatalc.csv').T.reset_index().replace('2016_Total','Virginia'))
VT= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/VT_fatalc.csv').T.reset_index().replace('2016_Total','Vermont'))
WA= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/WA_fatalc.csv').T.reset_index().replace('2016_Total','Washington'))
WI= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/WI_fatalc.csv').T.reset_index().replace('2016_Total','Wisconsin'))
WV= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/WV_fatalc.csv').T.reset_index().replace('2016_Total','West Virginia'))
WY= f_year2016(pd.read_csv('../data/cleaned_data/fatalities/WY_fatalc.csv').T.reset_index().replace('2016_Total', 'Wyoming'))

# %%
f_2016 = pd.concat([AL,AK,AR,AZ,CA,CO,CT,DE,DC,
FL,GA,HI,IA,ID,IL,IN,KS,KY,LA,
MA,ME,MD,MI,MN,MO,MS,
MT,NC,ND,NE,NH,NJ,NM,
NV,NY,OH,OK,OR,PA,
RI,SC,SD,TN,TX,UT,
VA,VT,WA,WI,WV,WY])

f_2016.to_csv('../data/cleaned_data/model_data/2016/f_2016.csv')

# %%
def f_year2017(df):
    df.columns = ['State','Total_Fatalities','Construction_Fatalities']
    df = df.iloc[8:9,:]
    df.set_index('State',drop=True,inplace=True)
    return df

# %%
# 2017
AL= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/AL_fatalc.csv').T.reset_index().replace('2017_Total','Alabama'))
AK= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/AK_fatalc.csv').T.reset_index().replace('2017_Total','Alaska'))
AR= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/AR_fatalc.csv').T.reset_index().replace('2017_Total','Arkansas'))
AZ= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/AZ_fatalc.csv').T.reset_index().replace('2017_Total','Arizona'))
CA= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/CA_fatalc.csv').T.reset_index().replace('2017_Total','California'))
CO= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/CO_fatalc.csv').T.reset_index().replace('2017_Total','Colorado'))
CT= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/CT_fatalc.csv').T.reset_index().replace('2017_Total','Connecticut'))
DE= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/DE_fatalc.csv').T.reset_index().replace('2017_Total','Delaware'))
DC= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/DC_fatalc.csv').T.reset_index().replace('2017_Total','District of Columbia'))
FL= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/FL_fatalc.csv').T.reset_index().replace('2017_Total','Florida'))
GA= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/GA_fatalc.csv').T.reset_index().replace('2017_Total','Georgia'))
HI= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/HI_fatalc.csv').T.reset_index().replace('2017_Total','Hawaii'))
IA= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/IA_fatalc.csv').T.reset_index().replace('2017_Total','Iowa'))
ID= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/ID_fatalc.csv').T.reset_index().replace('2017_Total','Idaho'))
IL= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/IL_fatalc.csv').T.reset_index().replace('2017_Total','Illinois'))
IN= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/IN_fatalc.csv').T.reset_index().replace('2017_Total','Indiana'))
KS= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/KS_fatalc.csv').T.reset_index().replace('2017_Total','Kansas'))
KY= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/KY_fatalc.csv').T.reset_index().replace('2017_Total','Kentucky'))
LA= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/LA_fatalc.csv').T.reset_index().replace('2017_Total','Louisiana'))
MA= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/MA_fatalc.csv').T.reset_index().replace('2017_Total','Massachusetts'))
ME= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/ME_fatalc.csv').T.reset_index().replace('2017_Total','Maine'))
MD= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/MD_fatalc.csv').T.reset_index().replace('2017_Total','Maryland'))
MI= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/MI_fatalc.csv').T.reset_index().replace('2017_Total','Michigan'))
MN= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/MN_fatalc.csv').T.reset_index().replace('2017_Total','Minnesota'))
MO= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/MO_fatalc.csv').T.reset_index().replace('2017_Total','Missouri'))
MS= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/MS_fatalc.csv').T.reset_index().replace('2017_Total','Mississippi'))
MT= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/MT_fatalc.csv').T.reset_index().replace('2017_Total','Montana'))
NC= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/NC_fatalc.csv').T.reset_index().replace('2017_Total','North Carolina'))
ND= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/ND_fatalc.csv').T.reset_index().replace('2017_Total','North Dakota'))
NE= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/NE_fatalc.csv').T.reset_index().replace('2017_Total','Nebraska'))
NH= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/NH_fatalc.csv').T.reset_index().replace('2017_Total','New Hampshire'))
NJ= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/NJ_fatalc.csv').T.reset_index().replace('2017_Total','New Jersey'))
NM= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/NM_fatalc.csv').T.reset_index().replace('2017_Total','New Mexico'))
NV= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/NV_fatalc.csv').T.reset_index().replace('2017_Total','Nevada'))
NY= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/NY_fatalc.csv').T.reset_index().replace('2017_Total','New York'))
OH= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/OH_fatalc.csv').T.reset_index().replace('2017_Total','Ohio'))
OK= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/OK_fatalc.csv').T.reset_index().replace('2017_Total','Oklahoma'))
OR= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/OR_fatalc.csv').T.reset_index().replace('2017_Total','Oregon'))
PA= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/PA_fatalc.csv').T.reset_index().replace('2017_Total','Pennsylvania'))
RI= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/RI_fatalc.csv').T.reset_index().replace('2017_Total','Rhode Island'))
SC= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/SC_fatalc.csv').T.reset_index().replace('2017_Total','South Carolina'))
SD= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/SD_fatalc.csv').T.reset_index().replace('2017_Total','South Dakota'))
TN= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/TN_fatalc.csv').T.reset_index().replace('2017_Total','Tennessee'))
TX= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/TX_fatalc.csv').T.reset_index().replace('2017_Total','Texas'))
UT= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/UT_fatalc.csv').T.reset_index().replace('2017_Total','Utah'))
VA= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/VA_fatalc.csv').T.reset_index().replace('2017_Total','Virginia'))
VT= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/VT_fatalc.csv').T.reset_index().replace('2017_Total','Vermont'))
WA= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/WA_fatalc.csv').T.reset_index().replace('2017_Total','Washington'))
WI= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/WI_fatalc.csv').T.reset_index().replace('2017_Total','Wisconsin'))
WV= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/WV_fatalc.csv').T.reset_index().replace('2017_Total','West Virginia'))
WY= f_year2017(pd.read_csv('../data/cleaned_data/fatalities/WY_fatalc.csv').T.reset_index().replace('2017_Total', 'Wyoming'))

# %%
f_2017 = pd.concat([AL,AK,AR,AZ,CA,CO,CT,DE,DC,
FL,GA,HI,IA,ID,IL,IN,KS,KY,LA,
MA,ME,MD,MI,MN,MO,MS,
MT,NC,ND,NE,NH,NJ,NM,
NV,NY,OH,OK,OR,PA,
RI,SC,SD,TN,TX,UT,
VA,VT,WA,WI,WV,WY])

f_2017.to_csv('../data/cleaned_data/model_data/2017/f_2017.csv')
