# %% [markdown]
# # Converting HTML Tables to Pandas Dataframes
#
# Much of the state fatality and injury information from the OSHA and US DOL websites is only available in HTML table form. We have used the following code to convert these tables into pandas dataframes to use in our model.

# %%
import pandas as pd
from IPython.display import HTML

# %% [markdown]
# ### Reading in and converting tables

# %%
WI_html = pd.read_html('../data/Wisconsin_fatal_table.html', index_col='Index')
WI = WI_html[0].T

# %%
WI.head()
# Out:
# Index                Total  Occupation (SOC)(5)  \
# Total FatalInjuries  106.0                  NaN
# Violence              20.0                  NaN
# Transpor-tation       35.0                  NaN
# Firesexplosions        7.0                  NaN
# Falls,slips,trips     18.0                  NaN
#
# Index                Management, business, science, and arts occupations  \
# Total FatalInjuries                                               37.0
# Violence                                                          11.0
# Transpor-tation                                                   13.0
# Firesexplosions                                                    NaN
# Falls,slips,trips                                                  5.0
#
# Index                Management occupations  \
# Total FatalInjuries                    27.0
# Violence                                6.0
# Transpor-tation                         9.0
# Firesexplosions                         NaN
# ...

# %%
NY_html = pd.read_html('../data/NY_fatal_table.html', index_col='Index')
NY = NY_html[0].T

# %%
WV_html = pd.read_html('../data/WV_fatal_table.html', index_col='Index')
WV = WV_html[0].T

# %%
CA_html = pd.read_html('../data/Cali_fatal_table.html', index_col='Index')
CA = CA_html[0].T

# %%
KY_html = pd.read_html('../data/Kentucky_fatal_table.html', index_col='Index')
KY = KY_html[0].T

# %%
AR_html = pd.read_html('../data/Arkansas_fatal_table.html', index_col='Index')
AR = AR_html[0].T

# %%
NH_html = pd.read_html('../data/NH_fatal_table.html', index_col='Index')
NH = NH_html[0].T

# %%
ME_html = pd.read_html('../data/Maine_fatal_table.html', index_col='Index')
ME = ME_html[0].T

# %%
AL_html = pd.read_html('../data/Alabama_fatal_table.html', index_col='Index')
AL = AL_html[0].T

# %%
LA_html = pd.read_html('../data/Louisiana_fatal_table.html', index_col='Index')
LA = LA_html[0].T
